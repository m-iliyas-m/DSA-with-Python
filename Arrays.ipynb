# %%
# "Divide and Rule?" – If you divide the list into smaller parts, think of:

# Quick Sort (pivot-based partitioning)

# Merge Sort (split and merge)

# "One by One?" – If you are handling elements step-by-step, it's:

# Bubble Sort (repeated swapping)

# Insertion Sort (insert in the right place)

# Selection Sort (select minimum/maximum)

# "Counting Things?" – If you count occurrences or categorize, it’s:

# Counting Sort (count frequency)

# Radix Sort (sort by digit positions)

# Bucket Sort (group into buckets)

# "Heap of Work?" – If you think of max/min priority, it’s:

# Heap Sort (binary heap)

# %%
import numpy as np
from IPython.display import Image

# %% [markdown]
# # Array Creation and Initialization

# %%
S = np.array([1,2,3,4])
S
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# # Accessing Array Elements

# %%
S[2:4]
# Out:
# array([3, 4])

# %% [markdown]
# # Modifying Array Elements

# %%
S[2] = 1
S
# Out:
# array([1, 2, 1, 4])

# %% [markdown]
# # Array Traversal

# %%
for i in S:
    print(i)
# Out:
# 1
# 2
# 1
# 4

# %% [markdown]
# # Array Insertion and Deletion

# %%
#insert at specific position
S = np.insert(S,3,10)
#for inserting in end of the array
S = np.append(S,10)
S
# Out:
# array([ 1,  2,  1, 10,  4, 10])

# %%
#use Del 
my_list = [1, 2, 3, 4, 5]
del my_list[2]  
print(my_list)
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# # Searching in Arrays (Linear Search, Binary Search)

# %%
Image(filename='img/Linear-Search.png')

# %% [markdown]
# ## linear Search without numpy

# %%
def Linearsearch(arr, target):
    for i in range(0,len(arr)):
        if (arr[i] == target):
            return i
    return -1
arr = [1,2,3,4,5,6,7,8,9]
target = 6
res = Linearsearch(arr,target)
print(f"Target element {target} found at index {res}")
# Out:
# Target element 6 found at index 5

# %% [markdown]
# ## linear Search using numpy

# %%
Arr = np.array([4,52,7,2,9,45,35,65])
target = 65
res = np.where(Arr == target)
if res[0].size > 0:
    print(f"Element {target} found at index {res[0][0]}.")
else:
    print(f"Element {target} not found in the array.")
# Out:
# Element 65 found at index 7.

# %% [markdown]
# ## Binary search without numpy

# %%
Image(filename='img/BinarySearch.png')

# %%
def Binarysearch(arr,target):
    low = 0
    high = len(arr)-1
    while(low <=high):
        mid= (high+low)//2
        mid_element = arr[mid]
        if(mid_element==target):
            return mid
        elif(mid_element<target):
            low = mid+1
        elif(mid_element>target):
            high = mid
    return -1   
Sorted_list = [11,23,45,56,58,59,64,66,78,79,91,96]
target = 91
res = Binarysearch(Sorted_list,target)
print(f"Target element {target} found at index {res}")
# Out:
# Target element 91 found at index 10

# %% [markdown]
# ## binary Search using numpy

# %%
Arr = np.array([11,23,45,56,58,59,64,66,78,79,91,96])
target = 91
res = np.searchsorted(Arr,target)
if res > 0:
    print(f"Element {target} found at index {res}.")
else:
    print(f"Element {target} not found in the array.")
# Out:
# Element 91 found at index 10.

# %% [markdown]
# # Sorting Arrays (Bubble Sort, Insertion Sort, Selection Sort, Merge Sort, Quick Sort)

# %% [markdown]
# ## Bubble Sort

# %%
Image(filename='img/BubbleSort.png')

# %%
def Bubblesort(Arr):
    n = len(Arr)
    for i in range(0,n):
        for j in range(0,n-1-i):
            if (Arr[j]>Arr[j+1]):
                Arr[j],Arr[j+1]=Arr[j+1],Arr[j]
Arr = [2,6,3,2,85,3,5,7,43,6,5,6,23,76,44,86,35,76,33,45,66,54,25,74,26,46,38,98,653,234,566,4,4564,6644]
Bubblesort(Arr)
print("Sorted Array" ,Arr)
# Out:
# Sorted Array [2, 2, 3, 3, 4, 5, 5, 6, 6, 6, 7, 23, 25, 26, 33, 35, 38, 43, 44, 45, 46, 54, 66, 74, 76, 76, 85, 86, 98, 234, 566, 653, 4564, 6644]

# %% [markdown]
# ## Insertion Sort

# %%
Image(filename='img/insertionsort.png')

# %%
def insertion_sort(arr):
    for i in range(1,len(arr)):
        key = arr[i]
        j = i - 1
        while j >=0 and key < arr[j]:
            arr[j+1]= arr[j]
            j -= 1    
        arr[j+1] = key
Arr = [2,6,3,2,85,3,5,7,43,6,5,6,23,76,44,86,35,76,33,45,66,54,25,74,26,46,38,98,653,234,566,4,4564,6644]
insertion_sort(Arr)
print("Sorted Array" ,Arr)
# Out:
# Sorted Array [2, 2, 3, 3, 4, 5, 5, 6, 6, 6, 7, 23, 25, 26, 33, 35, 38, 43, 44, 45, 46, 54, 66, 74, 76, 76, 85, 86, 98, 234, 566, 653, 4564, 6644]

# %% [markdown]
# ## Selection sort
# We start with the first element as the sorted part (i.e., i=0). The rest of the array is considered unsorted.
#
# We find the minimum element from the unsorted part (i.e., from index i+1 to the end of the array) and store its index in min_index
# .
# We swap the minimum element (at index min_index) with the first element of the unsorted part (at index i
# ).
# Now, the first i+1 elements are sorted, and the i+1th element is in its correct positi
# on.
# We repeat steps 2-4 until the entire array is sorted.

# %%
Image(filename='img/selection-short.png',width=400)

# %%
def sort_array(data):
    n = len(data)
    for i in range(n):
        for j in range(i+1,n):
            if arr[j]<arr[i]:
                arr[i],arr[j] =arr[j],arr[i]
            print(arr)
    return arr
arr = [66,34,22,5,3,12,76,24]
print(f"original data{arr}")
sort_array(arr)
# Out:
# original data[66, 34, 22, 5, 3, 12, 76, 24]
# [3, 5, 12, 22, 24, 34, 66, 76]

# %% [markdown]
# ## Merge Sort

# %%
Image(filename='img/Merge_sort.png',width=400)

# %% [markdown]
# ## Quick Sort

# %%
Image(filename='img/Quick-Sort.png',width=400)

# %% [markdown]
# # Merging and Splitting Arrays

# %% [markdown]
# ### Merging

# %%
def merge_arr(arr1,arr2):
    new_arr = []
    for i in arr1:
        new_arr.append(i)
    for i in arr2:    
        new_arr.append(i)
    return new_arr


arr1 = [1,2,3,4]
arr2 = [5,6,7,8]
merged_arr = merge_arr(arr1,arr2)
merged_arr
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ## Splitting

# %%
def Split_arr(arr, index):
    left = []
    right = []
    for i in range(0,len(arr)):
        if index > i:
            left.append(arr[i])
        else:
            right.append(arr[i])
    return left , right


arr = [1, 2, 3, 4, 5, 6, 7, 8]
index = 4
left , right = Split_arr(arr,index)
print(f"left arr = {left}\n right arr = {right}")
# Out:
# left arr = [1, 2, 3, 4]
#  right arr = [5, 6, 7, 8]

# %% [markdown]
# # Finding Maximum and Minimum Elements

# %%
def find_min_max(arr):
    min = arr[0]
    max = arr[0]
    for i in range(0,len(arr)):
        if min >arr[i]:
            min = arr[i]
        if max < arr[i]:
            max = arr[i]
    print(f"MAX - {max}\nMIN - {min}")
arr = [1,2,-3,4,5,56,7,8,9]
find_min_max(arr)
# Out:
# MAX - 56
# MIN - -3

# %% [markdown]
# # Array Reversal

# %%
def Reverse(arr):
    new_arr= []
    for i in range(len(arr)-1,-1,-1):
        new_arr += [arr[i]]
    return new_arr
        

arr = [1,2,3,4,5,6,7,8,9]
arr = Reverse(arr)
arr
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# # Subarray/Subsequence Problems

# %% [markdown]
# ## maximum subarray sum

# %%
def subarray_sum(arr):
    max_sum = 0
    sum = 0
    new_arr= []
    max_arr = []
    for i in range(0,len(arr)):
        for j in range(i,len(arr)):
            new_arr.append(arr[j])
            sum += arr[j]
            if sum > max_sum:
                max_sum = sum
                max_arr = new_arr
        sum = 0
        new_arr= []
    return max_sum,max_arr
arr = [1, -3, 4, -2, -1, 6]
sum,subarr = subarray_sum(arr)
sum , subarr
# Out:
# (7, [4, -2, -1, 6])

# %% [markdown]
# ## Longest Increasing Subsequence (Dynamic Programming)

# %%
def Longesgt_incresing_subsequence(arr):
    Long_sub_sequence = []
    flag = 0
    
    for i in range(0,len(arr)-1):
        for j in range(0,len(arr)-1):
            if arr[j] < arr[j+1]:
                Long_sub_sequence.append(arr[i])
                flag +=1
            else:
                break
               
    return Long_sub_sequence , flag
            

arr = [2,6,4,7,3,86,53,21,65,65,84,54,84,66,64,4]
sub,size = Longesgt_incresing_subsequence(arr)
sub,size
# Out:
# ([2, 6, 4, 7, 3, 86, 53, 21, 65, 65, 84, 54, 84, 66, 64], 15)

# %% [markdown]
# # Finding Duplicates in Arrays

# %%
def find_dup(arr):
    list = create_all_posible(arr)
    newlist = []
    for i in range(0,len(list)):
        temp = list[i]
        flag = 0
        for j in range(0,len(list)):
            if temp == list[j]:
                 flag +=1
        if flag >1:
            count = 0
            if not newlist:
                newlist.append(temp) 
            else:    
                for k in range(0,len(newlist)):
                    if newlist[k]==temp: 
                        count +=1
                if count >= 1:
                    count = 0
                    break
                else:
                    newlist.append(temp) 
                                    
    return newlist
def create_all_posible(arr):
     list=[]
     word=""
     for i in range(0,len(arr)):
        for j in range(i,len(arr)):
            word += str(arr[j])
            list.append(word)
        word=""
     return list
arr = np.array([1,2,3,4,1,2,3,1,2,3,4])
find_dup(arr)
# Out:
# ['1', '12', '123', '1234', '2', '23', '234', '3', '34', '4']
